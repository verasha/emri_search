# %%
import sys                                                                                                                                                                                                        
sys.path.insert(0, '/home/svu/e1498138/emri_search/work')                                                                                                                                                   
                                                                                                                                                                                                                    
from GWfuncs_noise import GravWaveAnalysis, build_waveform_response                                                                                                                                                 
from loglike_timemax_noise import LogLike                                                                                                                                                                           
import numpy as np                                                                                                                                                                                                        
import cupy as cp

# %%
use_gpu=True                                                                                                                                       
T = 12/12        # years                 
dt = 5       # seconds

# Source parameters
m1 = 1e6
m2 = 1e1
a = 0.7
p0 = 8.2
e0 = 0.4
xI0 = 1.0
dist = 9 # 9  # Gpc
qS = np.pi
phiS = 0.
qK =  0.
phiK = 0.
Phi_phi0 = 0.4
Phi_theta0 = 0.0
Phi_r0 = 0.5                                                                                                                           
                                                                                                                                                                                                                                                                                                                                                    
                                        
waveform_response = build_waveform_response(T=T, dt=dt, use_gpu=use_gpu,tdi_gen=1)

# %%
params=[m1,m2,a,p0,e0,xI0,dist,qS,phiS,qK,phiK,Phi_phi0,Phi_theta0,Phi_r0]

# %%
# n-indexed mode selection parameters
n_vals = np.arange(-1,6)  # n from -1 to 5
ell = 2  # quadrupole only

# %%
gwf = GravWaveAnalysis(T=T, dt=dt, use_gpu=True,tdi_gen=1)

# %%
# gwf_1yr = GravWaveAnalysis(T=1, dt=dt, use_gpu=True,tdi_gen=1)

# %%
loglike_obj= LogLike(                                                                                                                                                                                                       
    params=params,                                                                                                                                                                                                  
    waveform_response=waveform_response,                                                                                                                                                                            
    gwf=gwf,                                                                                                                                                                                                      
    add_noise=True,
    verbose=True,
    ell=ell,                                                                                                                                                                                                          
    n_vals=n_vals,
    M_mode=None,                                                                                                                                                                                                    
)
# Out:
# [INFO] Added colored noise with seed=0
# Delta_T for mode selection: 6311.629952709119 seconds
# Selected modes (l,m,n): [[(2, 0, -1), (2, 1, -1), (2, 2, -1), (2, -1, -1), (2, -2, -1)], [(2, 0, 0), (2, 1, 0), (2, 2, 0), (2, -1, 0), (2, -2, 0)], [(2, 0, 1), (2, 1, 1), (2, 2, 1), (2, -1, 1), (2, -2, 1)], [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, -1, 2), (2, -2, 2)], [(2, 0, 3), (2, 1, 3), (2, 2, 3), (2, -1, 3), (2, -2, 3)], [(2, 0, 4), (2, 1, 4), (2, 2, 4), (2, -1, 4), (2, -2, 4)], [(2, 0, 5), (2, 1, 5), (2, 2, 5), (2, -1, 5), (2, -2, 5)]]
# Selected modes: [[(2, 0, -1), (2, 1, -1), (2, 2, -1), (2, -1, -1), (2, -2, -1)], [(2, 0, 0), (2, 1, 0), (2, 2, 0), (2, -1, 0), (2, -2, 0)], [(2, 0, 1), (2, 1, 1), (2, 2, 1), (2, -1, 1), (2, -2, 1)], [(2, 0, 2), (2, 1, 2), (2, 2, 2), (2, -1, 2), (2, -2, 2)], [(2, 0, 3), (2, 1, 3), (2, 2, 3), (2, -1, 3), (2, -2, 3)], [(2, 0, 4), (2, 1, 4), (2, 2, 4), (2, -1, 4), (2, -2, 4)], [(2, 0, 5), (2, 1, 5), (2, 2, 5), (2, -1, 5), (2, -2, 5)]]
# Flattened modes: [(2, 0, -1), (2, 1, -1), (2, 2, -1), (2, -1, -1), (2, -2, -1), (2, 0, 0), (2, 1, 0), (2, 2, 0), (2, -1, 0), (2, -2, 0), (2, 0, 1), (2, 1, 1), (2, 2, 1), (2, -1, 1), (2, -2, 1), (2, 0, 2), (2, 1, 2), (2, 2, 2), (2, -1, 2), (2, -2, 2), (2, 0, 3), (2, 1, 3), (2, 2, 3), (2, -1, 3), (2, -2, 3), (2, 0, 4), (2, 1, 4), (2, 2, 4), (2, -1, 4), (2, -2, 4), (2, 0, 5), (2, 1, 5), (2, 2, 5), (2, -1, 5), (2, -2, 5)]

# %%
loglike_obj.signal
# Out:
# array([[ 2.29037824e-21, -5.96831485e-21,  1.52055623e-20, ...,
#          8.94321381e-21, -5.56764019e-21,  3.35656256e-21],
#        [ 1.27927097e-21, -1.87985533e-21,  1.62884555e-21, ...,
#         -1.40448937e-20,  8.05921996e-21, -9.80704172e-21],
#        [-1.10100941e-21,  1.19570151e-20, -1.61856432e-20, ...,
#         -2.16018325e-21, -7.88098485e-21,  7.26155734e-21]])

# %%
# %%time
#loglike at true param
logl_true=loglike_obj(params)
print(logl_true)
# Out:
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.658, rho=2.942
#   Mode 1: <hf|hf>_timemax=44.36, rho=6.66
#   Mode 2: <hf|hf>_timemax=119.4, rho=10.93
#   Mode 3: <hf|hf>_timemax=80.09, rho=8.949
#   Mode 4: <hf|hf>_timemax=31.26, rho=5.591
#   Mode 5: <hf|hf>_timemax=9.259, rho=3.043
#   Mode 6: <hf|hf>_timemax=2.339, rho=1.529
# rho_m: [ 2.94247764  6.6602001  10.92850321  8.94936781  5.59070851  3.04284451
#   1.52924069]
# Dominant mode index: 2, rho: 10.93
# beta=0.02239, rho_dom_M=10.93, rho_tot=18.25
# X_scalar (time-maximized): 18.06
# Time-maximized Log-likelihood: 16.9381
# 16.938118212494693
# CPU times: user 448 ms, sys: 17.3 ms, total: 465 ms
# Wall time: 518 ms

# %%
params_perturbed = list(params)                                                                                                                                                                                     
params_perturbed[0] *= 1.01                                                                                                                                                                                         
logl_perturbed = loglike_obj(params_perturbed)                                                                                                                                                                               
print(logl_perturbed)
# Out:
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.948, rho=2.819
#   Mode 1: <hf|hf>_timemax=40.64, rho=6.375
#   Mode 2: <hf|hf>_timemax=114.3, rho=10.69
#   Mode 3: <hf|hf>_timemax=78.73, rho=8.873
#   Mode 4: <hf|hf>_timemax=31.23, rho=5.588
#   Mode 5: <hf|hf>_timemax=9.324, rho=3.054
#   Mode 6: <hf|hf>_timemax=2.367, rho=1.538
# rho_m: [ 2.81914747  6.37514672 10.69245651  8.87312163  5.58794703  3.05352801
#   1.53842666]
# Dominant mode index: 2, rho: 10.69
# beta=0.02294, rho_dom_M=10.69, rho_tot=17.91
# X_scalar (time-maximized): 5.256
# Time-maximized Log-likelihood: 1.23324
# 1.2332415946012172

# %%
def logden_tm(params):
    logm1, logm2, a, p0, e0 = params
    return float(loglike_obj(np.array([10**logm1, 10**logm2, a, p0, e0,
                                    xI0, dist, qS, phiS, qK, phiK,
                                    Phi_phi0, Phi_theta0, Phi_r0])))

# %%
param_true = np.array([np.log10(m1), np.log10(m2), a, p0, e0])

# %%
# Sanity check at true params
print(logden_tm(param_true))
# Out:
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.658, rho=2.942
#   Mode 1: <hf|hf>_timemax=44.36, rho=6.66
#   Mode 2: <hf|hf>_timemax=119.4, rho=10.93
#   Mode 3: <hf|hf>_timemax=80.09, rho=8.949
#   Mode 4: <hf|hf>_timemax=31.26, rho=5.591
#   Mode 5: <hf|hf>_timemax=9.259, rho=3.043
#   Mode 6: <hf|hf>_timemax=2.339, rho=1.529
# rho_m: [ 2.94247764  6.6602001  10.92850321  8.94936781  5.59070851  3.04284451
#   1.52924069]
# Dominant mode index: 2, rho: 10.93
# beta=0.02239, rho_dom_M=10.93, rho_tot=18.25
# X_scalar (time-maximized): 18.06
# Time-maximized Log-likelihood: 16.9381
# 16.938118212494693

# %%
# # Sweep over logm2
# param_idx = 1  # logm2
# # param_secondary = np.array([6.29332246, 0.97236086, 0.3347499, 10.18644061, 0.34722833])

# param_range = np.sort(np.append(np.linspace(0.99, 1.01, 200), param_true[param_idx]))

# f_stats_tm   = np.zeros(len(param_range))
# # f_stats_pm   = np.zeros(len(param_range))
# # f_stats_pure = np.zeros(len(param_range))
# # f_stats_tmX = np.zeros(len(param_range))
# # X_pure = np.zeros(len(param_range))
# X_tm = np.zeros(len(param_range))
# X_tpm = np.zeros(len(param_range))
# X_sc = np.zeros(len(param_range))


# for i, val in enumerate(param_range):

#     p = param_true.copy()
#     p[param_idx] = val
#     # f_stats_tm[i]   = logden_tm(p)
#     # f_stats_pm[i]   = logden_pm(p)
#     # f_stats_pure[i] = logden_pure(p)
#     # f_stats_tmX[i] = logden_tmX(p)

#     # X only (no chi_sq)
#     logm1, logm2, a_i, p0_i, e0_i = p
#     h = gwf.xp.array(waveform_response(
#         10**logm1, 10**logm2, a_i, p0_i, e0_i,
#         xI0, dist, qS, phiS, qK, phiK,
#         Phi_phi0, Phi_theta0, Phi_r0, T=T, dt=dt,
#     ))
#     h_fft_r = gwf.freq_wave(h)
#     rho_h   = float(gwf.xp.sqrt(gwf.inner(h_fft_r, h_fft_r)))
#     # X_pure[i] = float(gwf.inner(loglike_obj.signal_fft, h_fft_r, return_complex=False)) / rho_h
#     # X_tm[i] = float(gwf.inner_timemax(loglike_obj.signal, h,phasemax=False)) / rho_h
#     # X_tpm[i] = float(gwf.inner_timemax(loglike_obj.signal, h,phasemax=True)) / rho_h
#     X_sc[i] = float(gwf.SNR_semicoherent(loglike_obj.signal, h, N_seg=12))

# %%
print('Initializing loglike_pure...')
params_star = [m1, m2, a, p0, e0, xI0, dist, qS, phiS, qK, phiK, Phi_phi0, Phi_theta0, Phi_r0]

import loglike_pure_noise
loglike_p = loglike_pure_noise.LogLike(
    params=params_star,
    waveform_response=waveform_response,
    gwf=gwf,
    add_noise=True,
    verbose=False,
    ell=ell, n_vals=n_vals, M_mode=None,
)
# Out:
# Initializing loglike_pure...

# %%
def logden_pure(params):
    logm1, logm2, a, p0, e0 = params
    return float(loglike_p(np.array([10**logm1, 10**logm2, a, p0, e0,
                                    xI0, dist, qS, phiS, qK, phiK,
                                    Phi_phi0, Phi_theta0, Phi_r0])))

# %%
# Sweep over logm2
param_idx = 1  # logm2
# param_secondary = np.array([6.29332246, 0.97236086, 0.3347499, 10.18644061, 0.34722833])

param_range = np.sort(np.append(np.linspace(0.975, 1.025, 100), param_true[param_idx]))

f_stats_tm   = np.zeros(len(param_range))
# f_stats_pm   = np.zeros(len(param_range))
f_stats_pure = np.zeros(len(param_range))
# f_stats_tmX = np.zeros(len(param_range))
# X_pure = np.zeros(len(param_range))
X_tm = np.zeros(len(param_range))
X_tpm = np.zeros(len(param_range))
Sfour = np.zeros(len(param_range))
Ssix = np.zeros(len(param_range))
Stwelve = np.zeros(len(param_range))
Ssixteen = np.zeros(len(param_range))
Sp= np.zeros(len(param_range))

for i, val in enumerate(param_range):

    p = param_true.copy()
    p[param_idx] = val
    f_stats_tm[i]   = logden_tm(p)
    # f_stats_pm[i]   = logden_pm(p)
    # f_stats_pure[i] = logden_pure(p)
    # f_stats_tmX[i] = logden_tmX(p)

    # X only (no chi_sq)
    logm1, logm2, a_i, p0_i, e0_i = p
    h = gwf.xp.array(waveform_response(
        10**logm1, 10**logm2, a_i, p0_i, e0_i,
        xI0, dist, qS, phiS, qK, phiK,
        Phi_phi0, Phi_theta0, Phi_r0, T=T, dt=dt,
    ))
    h_fft_r = gwf.freq_wave(h)
    rho_h   = float(gwf.xp.sqrt(gwf.inner(h_fft_r, h_fft_r)))
    # X_pure[i] = float(gwf.inner(loglike_obj.signal_fft, h_fft_r, return_complex=False)) / rho_h
    # X_tm[i] = float(gwf.inner_timemax(loglike_obj.signal, h)) / rho_h
    # X_tpm[i] = float(gwf.inner_timemax(loglike_obj.signal, h)) / rho_h
    # Sfour[i] = float(gwf.SNR_semicoherent(loglike_obj.signal, h, N_seg=4))
    # Ssix[i] = float(gwf.SNR_semicoherent(loglike_obj.signal, h, N_seg=6))
    Stwelve[i] = float(gwf.SNR_semicoherent(loglike_obj.signal, h, N_seg=12))
    # Ssixteen[i] = float(gwf.SNR_semicoherent(loglike_obj.signal, h, N_seg=16))
    Sp[i] = float(gwf.SNR_semicoherent_nomax(loglike_obj.signal, h, N_seg=12))
# Out:
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.755, rho=2.599
#   Mode 1: <hf|hf>_timemax=33.56, rho=5.793
#   Mode 2: <hf|hf>_timemax=99.8, rho=9.99
#   Mode 3: <hf|hf>_timemax=70.78, rho=8.413
#   Mode 4: <hf|hf>_timemax=28.52, rho=5.34
#   Mode 5: <hf|hf>_timemax=8.593, rho=2.931
#   Mode 6: <hf|hf>_timemax=2.19, rho=1.48
# rho_m: [2.59909976 5.79313329 9.98986627 8.41313273 5.3402374  2.9314443
#  1.48002346]
# Dominant mode index: 2, rho: 9.99
# beta=0.02528, rho_dom_M=9.99, rho_tot=16.79
# X_scalar (time-maximized): 5.109
# Time-maximized Log-likelihood: 1.22821
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.788, rho=2.605
#   Mode 1: <hf|hf>_timemax=33.73, rho=5.808
#   Mode 2: <hf|hf>_timemax=100.1, rho=10.01
#   Mode 3: <hf|hf>_timemax=70.94, rho=8.422
#   Mode 4: <hf|hf>_timemax=28.57, rho=5.345
#   Mode 5: <hf|hf>_timemax=8.611, rho=2.934
#   Mode 6: <hf|hf>_timemax=2.195, rho=1.482
# rho_m: [ 2.60532271  5.80804004 10.0066273   8.42241069  5.34493287  2.93436679
#   1.48155689]
# Dominant mode index: 2, rho: 10.01
# beta=0.02522, rho_dom_M=10.01, rho_tot=16.82
# X_scalar (time-maximized): 5.434
# Time-maximized Log-likelihood: 1.48083
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.821, rho=2.612
#   Mode 1: <hf|hf>_timemax=33.92, rho=5.824
#   Mode 2: <hf|hf>_timemax=100.5, rho=10.03
#   Mode 3: <hf|hf>_timemax=71.12, rho=8.433
#   Mode 4: <hf|hf>_timemax=28.6, rho=5.348
#   Mode 5: <hf|hf>_timemax=8.624, rho=2.937
#   Mode 6: <hf|hf>_timemax=2.195, rho=1.481
# rho_m: [ 2.61164796  5.82423494 10.02556493  8.4334036   5.34816073  2.93660545
#   1.48139078]
# Dominant mode index: 2, rho: 10.03
# beta=0.02516, rho_dom_M=10.03, rho_tot=16.84
# X_scalar (time-maximized): 5.442
# Time-maximized Log-likelihood: 1.6434
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.854, rho=2.618
#   Mode 1: <hf|hf>_timemax=34.1, rho=5.84
#   Mode 2: <hf|hf>_timemax=100.9, rho=10.04
#   Mode 3: <hf|hf>_timemax=71.31, rho=8.445
#   Mode 4: <hf|hf>_timemax=28.66, rho=5.354
#   Mode 5: <hf|hf>_timemax=8.634, rho=2.938
#   Mode 6: <hf|hf>_timemax=2.197, rho=1.482
# rho_m: [ 2.61797115  5.83990412 10.04361476  8.44477607  5.3535255   2.93829764
#   1.48225979]
# Dominant mode index: 2, rho: 10.04
# beta=0.02506, rho_dom_M=10.04, rho_tot=16.88
# X_scalar (time-maximized): 5.046
# Time-maximized Log-likelihood: 1.22719
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.887, rho=2.624
#   Mode 1: <hf|hf>_timemax=34.29, rho=5.856
#   Mode 2: <hf|hf>_timemax=101.2, rho=10.06
#   Mode 3: <hf|hf>_timemax=71.49, rho=8.455
#   Mode 4: <hf|hf>_timemax=28.73, rho=5.36
#   Mode 5: <hf|hf>_timemax=8.636, rho=2.939
#   Mode 6: <hf|hf>_timemax=2.202, rho=1.484
# rho_m: [ 2.62431865  5.85612442 10.06059816  8.45500505  5.36038687  2.93870904
#   1.48386517]
# Dominant mode index: 2, rho: 10.06
# beta=0.02495, rho_dom_M=10.06, rho_tot=16.92
# X_scalar (time-maximized): 5.254
# Time-maximized Log-likelihood: 1.40656
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.921, rho=2.631
#   Mode 1: <hf|hf>_timemax=34.48, rho=5.872
#   Mode 2: <hf|hf>_timemax=101.6, rho=10.08
#   Mode 3: <hf|hf>_timemax=71.64, rho=8.464
#   Mode 4: <hf|hf>_timemax=28.77, rho=5.364
#   Mode 5: <hf|hf>_timemax=8.658, rho=2.942
#   Mode 6: <hf|hf>_timemax=2.207, rho=1.486
# rho_m: [ 2.63086085  5.87217779 10.07948582  8.46394112  5.36371083  2.94248007
#   1.48564717]
# Dominant mode index: 2, rho: 10.08
# beta=0.02497, rho_dom_M=10.08, rho_tot=16.93
# X_scalar (time-maximized): 5.051
# Time-maximized Log-likelihood: 1.10319
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.954, rho=2.637
#   Mode 1: <hf|hf>_timemax=34.67, rho=5.888
#   Mode 2: <hf|hf>_timemax=102, rho=10.1
#   Mode 3: <hf|hf>_timemax=71.83, rho=8.475
#   Mode 4: <hf|hf>_timemax=28.82, rho=5.368
#   Mode 5: <hf|hf>_timemax=8.662, rho=2.943
#   Mode 6: <hf|hf>_timemax=2.206, rho=1.485
# rho_m: [ 2.63712824  5.88825245 10.0977172   8.47508851  5.36803024  2.94317502
#   1.48524517]
# Dominant mode index: 2, rho: 10.1
# beta=0.02493, rho_dom_M=10.1, rho_tot=16.96
# X_scalar (time-maximized): 4.935
# Time-maximized Log-likelihood: 1.08925
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=6.988, rho=2.644
#   Mode 1: <hf|hf>_timemax=34.87, rho=5.905
#   Mode 2: <hf|hf>_timemax=102.3, rho=10.12
#   Mode 3: <hf|hf>_timemax=72.02, rho=8.486
#   Mode 4: <hf|hf>_timemax=28.88, rho=5.374
#   Mode 5: <hf|hf>_timemax=8.685, rho=2.947
#   Mode 6: <hf|hf>_timemax=2.212, rho=1.487
# rho_m: [ 2.64351713  5.90487925 10.11550636  8.48616948  5.37446238  2.94709979
#   1.48741502]
# Dominant mode index: 2, rho: 10.12
# beta=0.02487, rho_dom_M=10.12, rho_tot=16.98
# X_scalar (time-maximized): 5.465
# Time-maximized Log-likelihood: 1.49128
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.023, rho=2.65
#   Mode 1: <hf|hf>_timemax=35.06, rho=5.921
#   Mode 2: <hf|hf>_timemax=102.7, rho=10.13
#   Mode 3: <hf|hf>_timemax=72.18, rho=8.496
#   Mode 4: <hf|hf>_timemax=28.94, rho=5.38
#   Mode 5: <hf|hf>_timemax=8.703, rho=2.95
#   Mode 6: <hf|hf>_timemax=2.216, rho=1.489
# rho_m: [ 2.65004927  5.92090098 10.13299365  8.49610181  5.37978555  2.95006762
#   1.48852193]
# Dominant mode index: 2, rho: 10.13
# beta=0.0248, rho_dom_M=10.13, rho_tot=17.01
# X_scalar (time-maximized): 5.271
# Time-maximized Log-likelihood: 1.33562
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.056, rho=2.656
#   Mode 1: <hf|hf>_timemax=35.26, rho=5.938
#   Mode 2: <hf|hf>_timemax=103.1, rho=10.15
#   Mode 3: <hf|hf>_timemax=72.37, rho=8.507
#   Mode 4: <hf|hf>_timemax=28.98, rho=5.384
#   Mode 5: <hf|hf>_timemax=8.716, rho=2.952
#   Mode 6: <hf|hf>_timemax=2.218, rho=1.489
# rho_m: [ 2.65632298  5.93759636 10.1533298   8.50690703  5.38369379  2.95226265
#   1.48914555]
# Dominant mode index: 2, rho: 10.15
# beta=0.02475, rho_dom_M=10.15, rho_tot=17.04
# X_scalar (time-maximized): 4.905
# Time-maximized Log-likelihood: 1.15553
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.092, rho=2.663
#   Mode 1: <hf|hf>_timemax=35.45, rho=5.954
#   Mode 2: <hf|hf>_timemax=103.4, rho=10.17
#   Mode 3: <hf|hf>_timemax=72.57, rho=8.519
#   Mode 4: <hf|hf>_timemax=29.03, rho=5.388
#   Mode 5: <hf|hf>_timemax=8.722, rho=2.953
#   Mode 6: <hf|hf>_timemax=2.222, rho=1.491
# rho_m: [ 2.66301156  5.95381162 10.17063387  8.51900963  5.38832754  2.95322393
#   1.49063819]
# Dominant mode index: 2, rho: 10.17
# beta=0.02469, rho_dom_M=10.17, rho_tot=17.07
# X_scalar (time-maximized): 5.229
# Time-maximized Log-likelihood: 1.36173
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.126, rho=2.669
#   Mode 1: <hf|hf>_timemax=35.65, rho=5.971
#   Mode 2: <hf|hf>_timemax=103.8, rho=10.19
#   Mode 3: <hf|hf>_timemax=72.74, rho=8.529
#   Mode 4: <hf|hf>_timemax=29.11, rho=5.395
#   Mode 5: <hf|hf>_timemax=8.728, rho=2.954
#   Mode 6: <hf|hf>_timemax=2.223, rho=1.491
# rho_m: [ 2.66943534  5.97056023 10.18906624  8.52871989  5.39536256  2.95435054
#   1.49106277]
# Dominant mode index: 2, rho: 10.19
# beta=0.02463, rho_dom_M=10.19, rho_tot=17.1
# X_scalar (time-maximized): 5.35
# Time-maximized Log-likelihood: 1.50404
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.162, rho=2.676
#   Mode 1: <hf|hf>_timemax=35.84, rho=5.987
#   Mode 2: <hf|hf>_timemax=104.2, rho=10.21
#   Mode 3: <hf|hf>_timemax=72.94, rho=8.54
#   Mode 4: <hf|hf>_timemax=29.14, rho=5.398
#   Mode 5: <hf|hf>_timemax=8.756, rho=2.959
#   Mode 6: <hf|hf>_timemax=2.223, rho=1.491
# rho_m: [ 2.67622927  5.98674049 10.20731436  8.54037669  5.39815572  2.95904878
#   1.49109997]
# Dominant mode index: 2, rho: 10.21
# beta=0.02456, rho_dom_M=10.21, rho_tot=17.13
# X_scalar (time-maximized): 5.172
# Time-maximized Log-likelihood: 1.19446
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.197, rho=2.683
#   Mode 1: <hf|hf>_timemax=36.04, rho=6.004
#   Mode 2: <hf|hf>_timemax=104.6, rho=10.23
#   Mode 3: <hf|hf>_timemax=73.09, rho=8.549
#   Mode 4: <hf|hf>_timemax=29.22, rho=5.406
#   Mode 5: <hf|hf>_timemax=8.756, rho=2.959
#   Mode 6: <hf|hf>_timemax=2.229, rho=1.493
# rho_m: [ 2.6827056   6.00370082 10.22598273  8.54941334  5.40586786  2.95897352
#   1.49293373]
# Dominant mode index: 2, rho: 10.23
# beta=0.02451, rho_dom_M=10.23, rho_tot=17.16
# X_scalar (time-maximized): 4.914
# Time-maximized Log-likelihood: 1.03614
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.232, rho=2.689
#   Mode 1: <hf|hf>_timemax=36.24, rho=6.02
#   Mode 2: <hf|hf>_timemax=105, rho=10.25
#   Mode 3: <hf|hf>_timemax=73.29, rho=8.561
#   Mode 4: <hf|hf>_timemax=29.27, rho=5.41
#   Mode 5: <hf|hf>_timemax=8.768, rho=2.961
#   Mode 6: <hf|hf>_timemax=2.234, rho=1.495
# rho_m: [ 2.68929286  6.01998042 10.24505724  8.56067304  5.41013004  2.96111851
#   1.49468026]
# Dominant mode index: 2, rho: 10.25
# beta=0.02444, rho_dom_M=10.25, rho_tot=17.19
# X_scalar (time-maximized): 5.563
# Time-maximized Log-likelihood: 1.65939
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.268, rho=2.696
#   Mode 1: <hf|hf>_timemax=36.44, rho=6.037
#   Mode 2: <hf|hf>_timemax=105.3, rho=10.26
#   Mode 3: <hf|hf>_timemax=73.48, rho=8.572
#   Mode 4: <hf|hf>_timemax=29.32, rho=5.415
#   Mode 5: <hf|hf>_timemax=8.783, rho=2.964
#   Mode 6: <hf|hf>_timemax=2.237, rho=1.496
# rho_m: [ 2.69595598  6.03688621 10.26276189  8.57230603  5.41470613  2.96360339
#   1.49554404]
# Dominant mode index: 2, rho: 10.26
# beta=0.02438, rho_dom_M=10.26, rho_tot=17.21
# X_scalar (time-maximized): 5.355
# Time-maximized Log-likelihood: 1.36519
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.304, rho=2.703
#   Mode 1: <hf|hf>_timemax=36.65, rho=6.054
#   Mode 2: <hf|hf>_timemax=105.7, rho=10.28
#   Mode 3: <hf|hf>_timemax=73.66, rho=8.583
#   Mode 4: <hf|hf>_timemax=29.38, rho=5.42
#   Mode 5: <hf|hf>_timemax=8.795, rho=2.966
#   Mode 6: <hf|hf>_timemax=2.24, rho=1.497
# rho_m: [ 2.70260982  6.05374882 10.28145783  8.5826757   5.42008944  2.96558496
#   1.49663626]
# Dominant mode index: 2, rho: 10.28
# beta=0.02433, rho_dom_M=10.28, rho_tot=17.24
# X_scalar (time-maximized): 5.266
# Time-maximized Log-likelihood: 1.29155
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.34, rho=2.709
#   Mode 1: <hf|hf>_timemax=36.85, rho=6.07
#   Mode 2: <hf|hf>_timemax=106.1, rho=10.3
#   Mode 3: <hf|hf>_timemax=73.82, rho=8.592
#   Mode 4: <hf|hf>_timemax=29.44, rho=5.426
#   Mode 5: <hf|hf>_timemax=8.809, rho=2.968
#   Mode 6: <hf|hf>_timemax=2.24, rho=1.497
# rho_m: [ 2.70931333  6.07045896 10.30078469  8.59211402  5.42612675  2.96795302
#   1.49667772]
# Dominant mode index: 2, rho: 10.3
# beta=0.02428, rho_dom_M=10.3, rho_tot=17.27
# X_scalar (time-maximized): 5.327
# Time-maximized Log-likelihood: 1.19128
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.377, rho=2.716
#   Mode 1: <hf|hf>_timemax=37.06, rho=6.088
#   Mode 2: <hf|hf>_timemax=106.5, rho=10.32
#   Mode 3: <hf|hf>_timemax=74.04, rho=8.604
#   Mode 4: <hf|hf>_timemax=29.47, rho=5.429
#   Mode 5: <hf|hf>_timemax=8.836, rho=2.972
#   Mode 6: <hf|hf>_timemax=2.242, rho=1.497
# rho_m: [ 2.71598358  6.0878552  10.31827668  8.60447314  5.42863716  2.97248419
#   1.49737142]
# Dominant mode index: 2, rho: 10.32
# beta=0.02422, rho_dom_M=10.32, rho_tot=17.3
# X_scalar (time-maximized): 5.138
# Time-maximized Log-likelihood: 1.20302
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.414, rho=2.723
#   Mode 1: <hf|hf>_timemax=37.26, rho=6.104
#   Mode 2: <hf|hf>_timemax=106.8, rho=10.34
#   Mode 3: <hf|hf>_timemax=74.24, rho=8.616
#   Mode 4: <hf|hf>_timemax=29.54, rho=5.435
#   Mode 5: <hf|hf>_timemax=8.834, rho=2.972
#   Mode 6: <hf|hf>_timemax=2.246, rho=1.499
# rho_m: [ 2.72285893  6.10449203 10.33645448  8.61600329  5.43526857  2.97228177
#   1.49852684]
# Dominant mode index: 2, rho: 10.34
# beta=0.02416, rho_dom_M=10.34, rho_tot=17.33
# X_scalar (time-maximized): 5.21
# Time-maximized Log-likelihood: 1.18795
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.45, rho=2.729
#   Mode 1: <hf|hf>_timemax=37.48, rho=6.122
#   Mode 2: <hf|hf>_timemax=107.3, rho=10.36
#   Mode 3: <hf|hf>_timemax=74.4, rho=8.626
#   Mode 4: <hf|hf>_timemax=29.58, rho=5.439
#   Mode 5: <hf|hf>_timemax=8.852, rho=2.975
#   Mode 6: <hf|hf>_timemax=2.251, rho=1.5
# rho_m: [ 2.72949308  6.12235233 10.35677588  8.62559942  5.43854849  2.97520677
#   1.50029486]
# Dominant mode index: 2, rho: 10.36
# beta=0.02411, rho_dom_M=10.36, rho_tot=17.36
# X_scalar (time-maximized): 5.469
# Time-maximized Log-likelihood: 1.40439
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.488, rho=2.736
#   Mode 1: <hf|hf>_timemax=37.69, rho=6.139
#   Mode 2: <hf|hf>_timemax=107.6, rho=10.37
#   Mode 3: <hf|hf>_timemax=74.58, rho=8.636
#   Mode 4: <hf|hf>_timemax=29.65, rho=5.445
#   Mode 5: <hf|hf>_timemax=8.873, rho=2.979
#   Mode 6: <hf|hf>_timemax=2.254, rho=1.501
# rho_m: [ 2.73634533  6.13915588 10.37389352  8.63620542  5.44534034  2.97876081
#   1.50146337]
# Dominant mode index: 2, rho: 10.37
# beta=0.02404, rho_dom_M=10.37, rho_tot=17.38
# X_scalar (time-maximized): 5.257
# Time-maximized Log-likelihood: 1.22778
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.526, rho=2.743
#   Mode 1: <hf|hf>_timemax=37.91, rho=6.157
#   Mode 2: <hf|hf>_timemax=108, rho=10.39
#   Mode 3: <hf|hf>_timemax=74.79, rho=8.648
#   Mode 4: <hf|hf>_timemax=29.72, rho=5.451
#   Mode 5: <hf|hf>_timemax=8.886, rho=2.981
#   Mode 6: <hf|hf>_timemax=2.256, rho=1.502
# rho_m: [ 2.74333961  6.15675417 10.39316578  8.64839471  5.45128384  2.98092269
#   1.5019462 ]
# Dominant mode index: 2, rho: 10.39
# beta=0.02398, rho_dom_M=10.39, rho_tot=17.41
# X_scalar (time-maximized): 4.995
# Time-maximized Log-likelihood: 1.10321
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.562, rho=2.75
#   Mode 1: <hf|hf>_timemax=38.11, rho=6.173
#   Mode 2: <hf|hf>_timemax=108.4, rho=10.41
#   Mode 3: <hf|hf>_timemax=74.98, rho=8.659
#   Mode 4: <hf|hf>_timemax=29.77, rho=5.456
#   Mode 5: <hf|hf>_timemax=8.891, rho=2.982
#   Mode 6: <hf|hf>_timemax=2.256, rho=1.502
# rho_m: [ 2.74999141  6.17337142 10.41316361  8.65899648  5.45611981  2.9817004
#   1.50209565]
# Dominant mode index: 2, rho: 10.41
# beta=0.02392, rho_dom_M=10.41, rho_tot=17.45
# X_scalar (time-maximized): 4.943
# Time-maximized Log-likelihood: 1.07977
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.601, rho=2.757
#   Mode 1: <hf|hf>_timemax=38.33, rho=6.191
#   Mode 2: <hf|hf>_timemax=108.8, rho=10.43
#   Mode 3: <hf|hf>_timemax=75.17, rho=8.67
#   Mode 4: <hf|hf>_timemax=29.8, rho=5.459
#   Mode 5: <hf|hf>_timemax=8.902, rho=2.984
#   Mode 6: <hf|hf>_timemax=2.264, rho=1.505
# rho_m: [ 2.75704883  6.19118799 10.43144113  8.66991341  5.4593334   2.98355082
#   1.50454636]
# Dominant mode index: 2, rho: 10.43
# beta=0.0238, rho_dom_M=10.43, rho_tot=17.49
# X_scalar (time-maximized): 5.212
# Time-maximized Log-likelihood: 1.2698
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.638, rho=2.764
#   Mode 1: <hf|hf>_timemax=38.54, rho=6.208
#   Mode 2: <hf|hf>_timemax=109.2, rho=10.45
#   Mode 3: <hf|hf>_timemax=75.35, rho=8.681
#   Mode 4: <hf|hf>_timemax=29.86, rho=5.465
#   Mode 5: <hf|hf>_timemax=8.927, rho=2.988
#   Mode 6: <hf|hf>_timemax=2.262, rho=1.504
# rho_m: [ 2.76377522  6.20822221 10.45032968  8.6806462   5.46457939  2.98782044
#   1.50392387]
# Dominant mode index: 2, rho: 10.45
# beta=0.02376, rho_dom_M=10.45, rho_tot=17.51
# X_scalar (time-maximized): 5.349
# Time-maximized Log-likelihood: 1.25619
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.677, rho=2.771
#   Mode 1: <hf|hf>_timemax=38.76, rho=6.226
#   Mode 2: <hf|hf>_timemax=109.6, rho=10.47
#   Mode 3: <hf|hf>_timemax=75.5, rho=8.689
#   Mode 4: <hf|hf>_timemax=29.94, rho=5.472
#   Mode 5: <hf|hf>_timemax=8.932, rho=2.989
#   Mode 6: <hf|hf>_timemax=2.266, rho=1.505
# rho_m: [ 2.77074589  6.225744   10.46993914  8.68928552  5.47152485  2.98861536
#   1.50520529]
# Dominant mode index: 2, rho: 10.47
# beta=0.02375, rho_dom_M=10.47, rho_tot=17.53
# X_scalar (time-maximized): 5.513
# Time-maximized Log-likelihood: 1.32824
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.715, rho=2.778
#   Mode 1: <hf|hf>_timemax=38.98, rho=6.243
#   Mode 2: <hf|hf>_timemax=110, rho=10.49
#   Mode 3: <hf|hf>_timemax=75.73, rho=8.702
#   Mode 4: <hf|hf>_timemax=29.98, rho=5.475
#   Mode 5: <hf|hf>_timemax=8.941, rho=2.99
#   Mode 6: <hf|hf>_timemax=2.269, rho=1.506
# rho_m: [ 2.77753427  6.24332268 10.48780454  8.70216131  5.47506413  2.99014913
#   1.50619682]
# Dominant mode index: 2, rho: 10.49
# beta=0.0237, rho_dom_M=10.49, rho_tot=17.56
# X_scalar (time-maximized): 5.687
# Time-maximized Log-likelihood: 1.40234
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.754, rho=2.785
#   Mode 1: <hf|hf>_timemax=39.2, rho=6.261
#   Mode 2: <hf|hf>_timemax=110.4, rho=10.51
#   Mode 3: <hf|hf>_timemax=75.88, rho=8.711
#   Mode 4: <hf|hf>_timemax=30.02, rho=5.479
#   Mode 5: <hf|hf>_timemax=8.954, rho=2.992
#   Mode 6: <hf|hf>_timemax=2.271, rho=1.507
# rho_m: [ 2.78457131  6.26128572 10.50644896  8.71105135  5.47901571  2.99235897
#   1.50688375]
# Dominant mode index: 2, rho: 10.51
# beta=0.02363, rho_dom_M=10.51, rho_tot=17.59
# X_scalar (time-maximized): 5.288
# Time-maximized Log-likelihood: 1.12664
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.793, rho=2.792
#   Mode 1: <hf|hf>_timemax=39.43, rho=6.279
#   Mode 2: <hf|hf>_timemax=110.8, rho=10.53
#   Mode 3: <hf|hf>_timemax=76.11, rho=8.724
#   Mode 4: <hf|hf>_timemax=30.08, rho=5.484
#   Mode 5: <hf|hf>_timemax=8.969, rho=2.995
#   Mode 6: <hf|hf>_timemax=2.279, rho=1.509
# rho_m: [ 2.79160682  6.27896683 10.52710845  8.72433684  5.48425763  2.99478419
#   1.50947843]
# Dominant mode index: 2, rho: 10.53
# beta=0.02352, rho_dom_M=10.53, rho_tot=17.64
# X_scalar (time-maximized): 4.908
# Time-maximized Log-likelihood: 1.03239
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.832, rho=2.799
#   Mode 1: <hf|hf>_timemax=39.66, rho=6.298
#   Mode 2: <hf|hf>_timemax=111.2, rho=10.54
#   Mode 3: <hf|hf>_timemax=76.3, rho=8.735
#   Mode 4: <hf|hf>_timemax=30.13, rho=5.489
#   Mode 5: <hf|hf>_timemax=8.995, rho=2.999
#   Mode 6: <hf|hf>_timemax=2.277, rho=1.509
# rho_m: [ 2.79861035  6.29758688 10.5446318   8.73482608  5.48914084  2.99909644
#   1.50901079]
# Dominant mode index: 2, rho: 10.54
# beta=0.0235, rho_dom_M=10.54, rho_tot=17.65
# X_scalar (time-maximized): 4.991
# Time-maximized Log-likelihood: 1.02829
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.873, rho=2.806
#   Mode 1: <hf|hf>_timemax=39.87, rho=6.315
#   Mode 2: <hf|hf>_timemax=111.6, rho=10.56
#   Mode 3: <hf|hf>_timemax=76.49, rho=8.746
#   Mode 4: <hf|hf>_timemax=30.19, rho=5.495
#   Mode 5: <hf|hf>_timemax=8.995, rho=2.999
#   Mode 6: <hf|hf>_timemax=2.283, rho=1.511
# rho_m: [ 2.80585219  6.31460715 10.56422894  8.74567246  5.4947871   2.99916151
#   1.51080295]
# Dominant mode index: 2, rho: 10.56
# beta=0.02346, rho_dom_M=10.56, rho_tot=17.68
# X_scalar (time-maximized): 5.142
# Time-maximized Log-likelihood: 1.08118
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.913, rho=2.813
#   Mode 1: <hf|hf>_timemax=40.11, rho=6.333
#   Mode 2: <hf|hf>_timemax=112, rho=10.58
#   Mode 3: <hf|hf>_timemax=76.68, rho=8.757
#   Mode 4: <hf|hf>_timemax=30.27, rho=5.502
#   Mode 5: <hf|hf>_timemax=9.023, rho=3.004
#   Mode 6: <hf|hf>_timemax=2.287, rho=1.512
# rho_m: [ 2.8129735   6.3330805  10.5846515   8.75663973  5.50173196  3.0038272
#   1.51225111]
# Dominant mode index: 2, rho: 10.58
# beta=0.02341, rho_dom_M=10.58, rho_tot=17.71
# X_scalar (time-maximized): 5.119
# Time-maximized Log-likelihood: 1.08634
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.954, rho=2.82
#   Mode 1: <hf|hf>_timemax=40.34, rho=6.351
#   Mode 2: <hf|hf>_timemax=112.4, rho=10.6
#   Mode 3: <hf|hf>_timemax=76.88, rho=8.768
#   Mode 4: <hf|hf>_timemax=30.3, rho=5.504
#   Mode 5: <hf|hf>_timemax=9.027, rho=3.004
#   Mode 6: <hf|hf>_timemax=2.289, rho=1.513
# rho_m: [ 2.82034873  6.35099539 10.60365841  8.76796418  5.50430007  3.00448901
#   1.51293593]
# Dominant mode index: 2, rho: 10.6
# beta=0.02325, rho_dom_M=10.6, rho_tot=17.76
# X_scalar (time-maximized): 5.064
# Time-maximized Log-likelihood: 1.22723
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=7.993, rho=2.827
#   Mode 1: <hf|hf>_timemax=40.56, rho=6.369
#   Mode 2: <hf|hf>_timemax=112.9, rho=10.62
#   Mode 3: <hf|hf>_timemax=77.03, rho=8.776
#   Mode 4: <hf|hf>_timemax=30.38, rho=5.512
#   Mode 5: <hf|hf>_timemax=9.038, rho=3.006
#   Mode 6: <hf|hf>_timemax=2.29, rho=1.513
# rho_m: [ 2.82724355  6.36884921 10.62312502  8.77645998  5.51217574  3.00631703
#   1.51314063]
# Dominant mode index: 2, rho: 10.62
# beta=0.02328, rho_dom_M=10.62, rho_tot=17.77
# X_scalar (time-maximized): 5.328
# Time-maximized Log-likelihood: 1.13564
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.035, rho=2.835
#   Mode 1: <hf|hf>_timemax=40.81, rho=6.388
#   Mode 2: <hf|hf>_timemax=113.3, rho=10.64
#   Mode 3: <hf|hf>_timemax=77.25, rho=8.789
#   Mode 4: <hf|hf>_timemax=30.43, rho=5.516
#   Mode 5: <hf|hf>_timemax=9.057, rho=3.009
#   Mode 6: <hf|hf>_timemax=2.295, rho=1.515
# rho_m: [ 2.83467374  6.38798071 10.64230537  8.78943011  5.51637428  3.00945729
#   1.51494808]
# Dominant mode index: 2, rho: 10.64
# beta=0.02323, rho_dom_M=10.64, rho_tot=17.8
# X_scalar (time-maximized): 5.178
# Time-maximized Log-likelihood: 1.38726
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.076, rho=2.842
#   Mode 1: <hf|hf>_timemax=41.04, rho=6.406
#   Mode 2: <hf|hf>_timemax=113.7, rho=10.66
#   Mode 3: <hf|hf>_timemax=77.41, rho=8.798
#   Mode 4: <hf|hf>_timemax=30.48, rho=5.521
#   Mode 5: <hf|hf>_timemax=9.074, rho=3.012
#   Mode 6: <hf|hf>_timemax=2.295, rho=1.515
# rho_m: [ 2.84176023  6.40605816 10.66088303  8.79833011  5.52106832  3.01236157
#   1.51498033]
# Dominant mode index: 2, rho: 10.66
# beta=0.02309, rho_dom_M=10.66, rho_tot=17.85
# X_scalar (time-maximized): 5.068
# Time-maximized Log-likelihood: 1.06928
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.117, rho=2.849
#   Mode 1: <hf|hf>_timemax=41.27, rho=6.424
#   Mode 2: <hf|hf>_timemax=114, rho=10.68
#   Mode 3: <hf|hf>_timemax=77.64, rho=8.811
#   Mode 4: <hf|hf>_timemax=30.54, rho=5.527
#   Mode 5: <hf|hf>_timemax=9.075, rho=3.012
#   Mode 6: <hf|hf>_timemax=2.3, rho=1.516
# rho_m: [ 2.84904377  6.4244844  10.67918423  8.81128082  5.52666824  3.01248225
#   1.51646649]
# Dominant mode index: 2, rho: 10.68
# beta=0.0231, rho_dom_M=10.68, rho_tot=17.86
# X_scalar (time-maximized): 5.468
# Time-maximized Log-likelihood: 1.2648
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.159, rho=2.856
#   Mode 1: <hf|hf>_timemax=41.51, rho=6.443
#   Mode 2: <hf|hf>_timemax=114.5, rho=10.7
#   Mode 3: <hf|hf>_timemax=77.84, rho=8.823
#   Mode 4: <hf|hf>_timemax=30.61, rho=5.532
#   Mode 5: <hf|hf>_timemax=9.098, rho=3.016
#   Mode 6: <hf|hf>_timemax=2.303, rho=1.517
# rho_m: [ 2.85643543  6.44293796 10.69986281  8.82272643  5.53225345  3.01630909
#   1.51749293]
# Dominant mode index: 2, rho: 10.7
# beta=0.02305, rho_dom_M=10.7, rho_tot=17.89
# X_scalar (time-maximized): 4.822
# Time-maximized Log-likelihood: 0.922527
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.2, rho=2.864
#   Mode 1: <hf|hf>_timemax=41.74, rho=6.46
#   Mode 2: <hf|hf>_timemax=114.9, rho=10.72
#   Mode 3: <hf|hf>_timemax=78.03, rho=8.834
#   Mode 4: <hf|hf>_timemax=30.63, rho=5.535
#   Mode 5: <hf|hf>_timemax=9.116, rho=3.019
#   Mode 6: <hf|hf>_timemax=2.304, rho=1.518
# rho_m: [ 2.86361715  6.4603771  10.7189988   8.83371318  5.5348498   3.01932397
#   1.5180326 ]
# Dominant mode index: 2, rho: 10.72
# beta=0.02293, rho_dom_M=10.72, rho_tot=17.94
# X_scalar (time-maximized): 5.374
# Time-maximized Log-likelihood: 1.19797
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.243, rho=2.871
#   Mode 1: <hf|hf>_timemax=41.98, rho=6.479
#   Mode 2: <hf|hf>_timemax=115.3, rho=10.74
#   Mode 3: <hf|hf>_timemax=78.22, rho=8.844
#   Mode 4: <hf|hf>_timemax=30.72, rho=5.543
#   Mode 5: <hf|hf>_timemax=9.128, rho=3.021
#   Mode 6: <hf|hf>_timemax=2.309, rho=1.519
# rho_m: [ 2.87102027  6.47928888 10.73859664  8.84422269  5.54262742  3.02123647
#   1.51948134]
# Dominant mode index: 2, rho: 10.74
# beta=0.02293, rho_dom_M=10.74, rho_tot=17.95
# X_scalar (time-maximized): 5.378
# Time-maximized Log-likelihood: 1.32333
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.285, rho=2.878
#   Mode 1: <hf|hf>_timemax=42.23, rho=6.499
#   Mode 2: <hf|hf>_timemax=115.7, rho=10.76
#   Mode 3: <hf|hf>_timemax=78.38, rho=8.853
#   Mode 4: <hf|hf>_timemax=30.76, rho=5.546
#   Mode 5: <hf|hf>_timemax=9.144, rho=3.024
#   Mode 6: <hf|hf>_timemax=2.311, rho=1.52
# rho_m: [ 2.87840987  6.4988015  10.75871511  8.85324985  5.54621512  3.02393829
#   1.52023299]
# Dominant mode index: 2, rho: 10.76
# beta=0.02282, rho_dom_M=10.76, rho_tot=18
# X_scalar (time-maximized): 5.314
# Time-maximized Log-likelihood: 1.17289
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.328, rho=2.886
#   Mode 1: <hf|hf>_timemax=42.47, rho=6.517
#   Mode 2: <hf|hf>_timemax=116.2, rho=10.78
#   Mode 3: <hf|hf>_timemax=78.61, rho=8.866
#   Mode 4: <hf|hf>_timemax=30.81, rho=5.551
#   Mode 5: <hf|hf>_timemax=9.144, rho=3.024
#   Mode 6: <hf|hf>_timemax=2.317, rho=1.522
# rho_m: [ 2.88578567  6.51683873 10.7783338   8.86635376  5.55054163  3.02395772
#   1.52219059]
# Dominant mode index: 2, rho: 10.78
# beta=0.02282, rho_dom_M=10.78, rho_tot=18.02
# X_scalar (time-maximized): 5.053
# Time-maximized Log-likelihood: 0.960346
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.372, rho=2.893
#   Mode 1: <hf|hf>_timemax=42.71, rho=6.535
#   Mode 2: <hf|hf>_timemax=116.6, rho=10.8
#   Mode 3: <hf|hf>_timemax=78.77, rho=8.875
#   Mode 4: <hf|hf>_timemax=30.87, rho=5.556
#   Mode 5: <hf|hf>_timemax=9.162, rho=3.027
#   Mode 6: <hf|hf>_timemax=2.321, rho=1.523
# rho_m: [ 2.8933961   6.53548699 10.79811083  8.87523874  5.55565278  3.02684178
#   1.52332678]
# Dominant mode index: 2, rho: 10.8
# beta=0.02275, rho_dom_M=10.8, rho_tot=18.05
# X_scalar (time-maximized): 5.162
# Time-maximized Log-likelihood: 1.07989
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.414, rho=2.901
#   Mode 1: <hf|hf>_timemax=42.97, rho=6.555
#   Mode 2: <hf|hf>_timemax=117, rho=10.82
#   Mode 3: <hf|hf>_timemax=79.01, rho=8.889
#   Mode 4: <hf|hf>_timemax=30.93, rho=5.562
#   Mode 5: <hf|hf>_timemax=9.169, rho=3.028
#   Mode 6: <hf|hf>_timemax=2.323, rho=1.524
# rho_m: [ 2.90075068  6.55506172 10.81660451  8.88876558  5.56154466  3.02807575
#   1.52402721]
# Dominant mode index: 2, rho: 10.82
# beta=0.0227, rho_dom_M=10.82, rho_tot=18.08
# X_scalar (time-maximized): 5.284
# Time-maximized Log-likelihood: 1.27165
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.458, rho=2.908
#   Mode 1: <hf|hf>_timemax=43.21, rho=6.573
#   Mode 2: <hf|hf>_timemax=117.5, rho=10.84
#   Mode 3: <hf|hf>_timemax=79.2, rho=8.9
#   Mode 4: <hf|hf>_timemax=31, rho=5.568
#   Mode 5: <hf|hf>_timemax=9.189, rho=3.031
#   Mode 6: <hf|hf>_timemax=2.323, rho=1.524
# rho_m: [ 2.90829645  6.57313409 10.83881733  8.89958045  5.5679114   3.03130614
#   1.52400108]
# Dominant mode index: 2, rho: 10.84
# beta=0.02264, rho_dom_M=10.84, rho_tot=18.11
# X_scalar (time-maximized): 5.1
# Time-maximized Log-likelihood: 0.994383
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.503, rho=2.916
#   Mode 1: <hf|hf>_timemax=43.46, rho=6.592
#   Mode 2: <hf|hf>_timemax=117.9, rho=10.86
#   Mode 3: <hf|hf>_timemax=79.4, rho=8.911
#   Mode 4: <hf|hf>_timemax=31.03, rho=5.571
#   Mode 5: <hf|hf>_timemax=9.203, rho=3.034
#   Mode 6: <hf|hf>_timemax=2.329, rho=1.526
# rho_m: [ 2.91601972  6.59212367 10.85755357  8.9105755   5.57063826  3.03367395
#   1.52609579]
# Dominant mode index: 2, rho: 10.86
# beta=0.02259, rho_dom_M=10.86, rho_tot=18.14
# X_scalar (time-maximized): 5.011
# Time-maximized Log-likelihood: 0.958201
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.546, rho=2.923
#   Mode 1: <hf|hf>_timemax=43.71, rho=6.611
#   Mode 2: <hf|hf>_timemax=118.3, rho=10.88
#   Mode 3: <hf|hf>_timemax=79.6, rho=8.922
#   Mode 4: <hf|hf>_timemax=31.1, rho=5.577
#   Mode 5: <hf|hf>_timemax=9.21, rho=3.035
#   Mode 6: <hf|hf>_timemax=2.328, rho=1.526
# rho_m: [ 2.92340099  6.61134809 10.87851007  8.92190883  5.57714085  3.03484023
#   1.52562758]
# Dominant mode index: 2, rho: 10.88
# beta=0.02252, rho_dom_M=10.88, rho_tot=18.17
# X_scalar (time-maximized): 4.987
# Time-maximized Log-likelihood: 0.999131
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.592, rho=2.931
#   Mode 1: <hf|hf>_timemax=43.98, rho=6.632
#   Mode 2: <hf|hf>_timemax=118.7, rho=10.9
#   Mode 3: <hf|hf>_timemax=79.78, rho=8.932
#   Mode 4: <hf|hf>_timemax=31.17, rho=5.583
#   Mode 5: <hf|hf>_timemax=9.226, rho=3.037
#   Mode 6: <hf|hf>_timemax=2.331, rho=1.527
# rho_m: [ 2.9311416   6.63153667 10.89630206  8.9317916   5.58313836  3.03747729
#   1.52680955]
# Dominant mode index: 2, rho: 10.9
# beta=0.02247, rho_dom_M=10.9, rho_tot=18.2
# X_scalar (time-maximized): 5.048
# Time-maximized Log-likelihood: 0.970909
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.636, rho=2.939
#   Mode 1: <hf|hf>_timemax=44.22, rho=6.65
#   Mode 2: <hf|hf>_timemax=119.2, rho=10.92
#   Mode 3: <hf|hf>_timemax=79.98, rho=8.943
#   Mode 4: <hf|hf>_timemax=31.23, rho=5.588
#   Mode 5: <hf|hf>_timemax=9.243, rho=3.04
#   Mode 6: <hf|hf>_timemax=2.334, rho=1.528
# rho_m: [ 2.93867273  6.64997423 10.91667344  8.9431921   5.58798493  3.04025871
#   1.52764139]
# Dominant mode index: 2, rho: 10.92
# beta=0.02235, rho_dom_M=10.92, rho_tot=18.25
# X_scalar (time-maximized): 5.328
# Time-maximized Log-likelihood: 1.11417
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.658, rho=2.942
#   Mode 1: <hf|hf>_timemax=44.36, rho=6.66
#   Mode 2: <hf|hf>_timemax=119.4, rho=10.93
#   Mode 3: <hf|hf>_timemax=80.09, rho=8.949
#   Mode 4: <hf|hf>_timemax=31.26, rho=5.591
#   Mode 5: <hf|hf>_timemax=9.259, rho=3.043
#   Mode 6: <hf|hf>_timemax=2.339, rho=1.529
# rho_m: [ 2.94247764  6.6602001  10.92850321  8.94936781  5.59070851  3.04284451
#   1.52924069]
# Dominant mode index: 2, rho: 10.93
# beta=0.02239, rho_dom_M=10.93, rho_tot=18.25
# X_scalar (time-maximized): 18.06
# Time-maximized Log-likelihood: 16.9381
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.681, rho=2.946
#   Mode 1: <hf|hf>_timemax=44.48, rho=6.67
#   Mode 2: <hf|hf>_timemax=119.6, rho=10.94
#   Mode 3: <hf|hf>_timemax=80.19, rho=8.955
#   Mode 4: <hf|hf>_timemax=31.29, rho=5.593
#   Mode 5: <hf|hf>_timemax=9.264, rho=3.044
#   Mode 6: <hf|hf>_timemax=2.339, rho=1.529
# rho_m: [ 2.94637824  6.66956537 10.93707056  8.95476433  5.59338128  3.04365325
#   1.52949915]
# Dominant mode index: 2, rho: 10.94
# beta=0.02236, rho_dom_M=10.94, rho_tot=18.26
# X_scalar (time-maximized): 5.136
# Time-maximized Log-likelihood: 1.05355
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.727, rho=2.954
#   Mode 1: <hf|hf>_timemax=44.75, rho=6.69
#   Mode 2: <hf|hf>_timemax=120, rho=10.96
#   Mode 3: <hf|hf>_timemax=80.39, rho=8.966
#   Mode 4: <hf|hf>_timemax=31.31, rho=5.596
#   Mode 5: <hf|hf>_timemax=9.27, rho=3.045
#   Mode 6: <hf|hf>_timemax=2.342, rho=1.53
# rho_m: [ 2.95408478  6.68969055 10.95651757  8.9659905   5.59596225  3.0446932
#   1.53024731]
# Dominant mode index: 2, rho: 10.96
# beta=0.02226, rho_dom_M=10.96, rho_tot=18.31
# X_scalar (time-maximized): 5.616
# Time-maximized Log-likelihood: 1.36983
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.772, rho=2.962
#   Mode 1: <hf|hf>_timemax=45, rho=6.708
#   Mode 2: <hf|hf>_timemax=120.5, rho=10.98
#   Mode 3: <hf|hf>_timemax=80.58, rho=8.977
#   Mode 4: <hf|hf>_timemax=31.38, rho=5.602
#   Mode 5: <hf|hf>_timemax=9.286, rho=3.047
#   Mode 6: <hf|hf>_timemax=2.347, rho=1.532
# rho_m: [ 2.96181884  6.70826876 10.97742586  8.97676477  5.60213653  3.04736504
#   1.53213385]
# Dominant mode index: 2, rho: 10.98
# beta=0.02225, rho_dom_M=10.98, rho_tot=18.33
# X_scalar (time-maximized): 5.257
# Time-maximized Log-likelihood: 1.19726
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.819, rho=2.97
#   Mode 1: <hf|hf>_timemax=45.27, rho=6.728
#   Mode 2: <hf|hf>_timemax=121, rho=11
#   Mode 3: <hf|hf>_timemax=80.78, rho=8.988
#   Mode 4: <hf|hf>_timemax=31.43, rho=5.606
#   Mode 5: <hf|hf>_timemax=9.306, rho=3.051
#   Mode 6: <hf|hf>_timemax=2.348, rho=1.532
# rho_m: [ 2.96964093  6.72803605 10.99807622  8.9876817   5.60587142  3.05059652
#   1.53233939]
# Dominant mode index: 2, rho: 11
# beta=0.02219, rho_dom_M=11, rho_tot=18.36
# X_scalar (time-maximized): 4.927
# Time-maximized Log-likelihood: 1.06074
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.865, rho=2.977
#   Mode 1: <hf|hf>_timemax=45.53, rho=6.748
#   Mode 2: <hf|hf>_timemax=121.4, rho=11.02
#   Mode 3: <hf|hf>_timemax=80.99, rho=8.999
#   Mode 4: <hf|hf>_timemax=31.51, rho=5.613
#   Mode 5: <hf|hf>_timemax=9.304, rho=3.05
#   Mode 6: <hf|hf>_timemax=2.352, rho=1.534
# rho_m: [ 2.97737451  6.74779493 11.01700827  8.99932196  5.61341508  3.05030429
#   1.53370316]
# Dominant mode index: 2, rho: 11.02
# beta=0.02204, rho_dom_M=11.02, rho_tot=18.42
# X_scalar (time-maximized): 4.989
# Time-maximized Log-likelihood: 1.03023
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.913, rho=2.985
#   Mode 1: <hf|hf>_timemax=45.81, rho=6.768
#   Mode 2: <hf|hf>_timemax=121.8, rho=11.04
#   Mode 3: <hf|hf>_timemax=81.2, rho=9.011
#   Mode 4: <hf|hf>_timemax=31.57, rho=5.619
#   Mode 5: <hf|hf>_timemax=9.333, rho=3.055
#   Mode 6: <hf|hf>_timemax=2.356, rho=1.535
# rho_m: [ 2.98549397  6.7680905  11.03828463  9.01087997  5.61878426  3.05505637
#   1.53486538]
# Dominant mode index: 2, rho: 11.04
# beta=0.02208, rho_dom_M=11.04, rho_tot=18.42
# X_scalar (time-maximized): 5.091
# Time-maximized Log-likelihood: 1.05151
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=8.958, rho=2.993
#   Mode 1: <hf|hf>_timemax=46.07, rho=6.788
#   Mode 2: <hf|hf>_timemax=122.3, rho=11.06
#   Mode 3: <hf|hf>_timemax=81.35, rho=9.019
#   Mode 4: <hf|hf>_timemax=31.62, rho=5.623
#   Mode 5: <hf|hf>_timemax=9.341, rho=3.056
#   Mode 6: <hf|hf>_timemax=2.355, rho=1.535
# rho_m: [ 2.99297292  6.78768721 11.05981004  9.01947722  5.62346264  3.05626037
#   1.53451605]
# Dominant mode index: 2, rho: 11.06
# beta=0.02202, rho_dom_M=11.06, rho_tot=18.45
# X_scalar (time-maximized): 5.457
# Time-maximized Log-likelihood: 1.30949
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.006, rho=3.001
#   Mode 1: <hf|hf>_timemax=46.34, rho=6.807
#   Mode 2: <hf|hf>_timemax=122.7, rho=11.08
#   Mode 3: <hf|hf>_timemax=81.6, rho=9.033
#   Mode 4: <hf|hf>_timemax=31.65, rho=5.626
#   Mode 5: <hf|hf>_timemax=9.352, rho=3.058
#   Mode 6: <hf|hf>_timemax=2.36, rho=1.536
# rho_m: [ 3.00107013  6.80722344 11.07854295  9.03312222  5.62602456  3.05807061
#   1.53634986]
# Dominant mode index: 2, rho: 11.08
# beta=0.02188, rho_dom_M=11.08, rho_tot=18.51
# X_scalar (time-maximized): 5.099
# Time-maximized Log-likelihood: 1.01405
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.053, rho=3.009
#   Mode 1: <hf|hf>_timemax=46.62, rho=6.828
#   Mode 2: <hf|hf>_timemax=123.2, rho=11.1
#   Mode 3: <hf|hf>_timemax=81.79, rho=9.044
#   Mode 4: <hf|hf>_timemax=31.73, rho=5.633
#   Mode 5: <hf|hf>_timemax=9.373, rho=3.062
#   Mode 6: <hf|hf>_timemax=2.365, rho=1.538
# rho_m: [ 3.00884792  6.82769544 11.09879655  9.04374553  5.63287326  3.06155477
#   1.53793535]
# Dominant mode index: 2, rho: 11.1
# beta=0.0219, rho_dom_M=11.1, rho_tot=18.52
# X_scalar (time-maximized): 5.151
# Time-maximized Log-likelihood: 1.14847
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.104, rho=3.017
#   Mode 1: <hf|hf>_timemax=46.9, rho=6.849
#   Mode 2: <hf|hf>_timemax=123.7, rho=11.12
#   Mode 3: <hf|hf>_timemax=81.97, rho=9.054
#   Mode 4: <hf|hf>_timemax=31.77, rho=5.636
#   Mode 5: <hf|hf>_timemax=9.377, rho=3.062
#   Mode 6: <hf|hf>_timemax=2.367, rho=1.539
# rho_m: [ 3.01725148  6.84864647 11.12072229  9.05364153  5.63614325  3.06223544
#   1.53866025]
# Dominant mode index: 2, rho: 11.12
# beta=0.02185, rho_dom_M=11.12, rho_tot=18.55
# X_scalar (time-maximized): 5.291
# Time-maximized Log-likelihood: 1.1586
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.151, rho=3.025
#   Mode 1: <hf|hf>_timemax=47.17, rho=6.868
#   Mode 2: <hf|hf>_timemax=124.1, rho=11.14
#   Mode 3: <hf|hf>_timemax=82.17, rho=9.065
#   Mode 4: <hf|hf>_timemax=31.85, rho=5.644
#   Mode 5: <hf|hf>_timemax=9.391, rho=3.065
#   Mode 6: <hf|hf>_timemax=2.368, rho=1.539
# rho_m: [ 3.02500372  6.86818731 11.14087624  9.06486541  5.64357837  3.0645374
#   1.53878808]
# Dominant mode index: 2, rho: 11.14
# beta=0.02179, rho_dom_M=11.14, rho_tot=18.58
# X_scalar (time-maximized): 5.362
# Time-maximized Log-likelihood: 1.23733
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.2, rho=3.033
#   Mode 1: <hf|hf>_timemax=47.46, rho=6.889
#   Mode 2: <hf|hf>_timemax=124.6, rho=11.16
#   Mode 3: <hf|hf>_timemax=82.4, rho=9.077
#   Mode 4: <hf|hf>_timemax=31.91, rho=5.649
#   Mode 5: <hf|hf>_timemax=9.399, rho=3.066
#   Mode 6: <hf|hf>_timemax=2.374, rho=1.541
# rho_m: [ 3.03315435  6.88911754 11.16079574  9.0774068   5.6491888   3.06585882
#   1.54074872]
# Dominant mode index: 2, rho: 11.16
# beta=0.02163, rho_dom_M=11.16, rho_tot=18.65
# X_scalar (time-maximized): 5.44
# Time-maximized Log-likelihood: 1.32133
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.249, rho=3.041
#   Mode 1: <hf|hf>_timemax=47.73, rho=6.909
#   Mode 2: <hf|hf>_timemax=125.1, rho=11.18
#   Mode 3: <hf|hf>_timemax=82.61, rho=9.089
#   Mode 4: <hf|hf>_timemax=31.96, rho=5.654
#   Mode 5: <hf|hf>_timemax=9.414, rho=3.068
#   Mode 6: <hf|hf>_timemax=2.373, rho=1.54
# rho_m: [ 3.04123544  6.90854297 11.18289491  9.08918382  5.65351706  3.06827364
#   1.54044035]
# Dominant mode index: 2, rho: 11.18
# beta=0.02167, rho_dom_M=11.18, rho_tot=18.65
# X_scalar (time-maximized): 5.029
# Time-maximized Log-likelihood: 0.955728
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.299, rho=3.049
#   Mode 1: <hf|hf>_timemax=48.01, rho=6.929
#   Mode 2: <hf|hf>_timemax=125.5, rho=11.2
#   Mode 3: <hf|hf>_timemax=82.77, rho=9.098
#   Mode 4: <hf|hf>_timemax=32, rho=5.656
#   Mode 5: <hf|hf>_timemax=9.427, rho=3.07
#   Mode 6: <hf|hf>_timemax=2.377, rho=1.542
# rho_m: [ 3.04938887  6.9291273  11.20110304  9.0979208   5.6564201   3.07031611
#   1.54167332]
# Dominant mode index: 2, rho: 11.2
# beta=0.02162, rho_dom_M=11.2, rho_tot=18.68
# X_scalar (time-maximized): 5.338
# Time-maximized Log-likelihood: 1.1268
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.348, rho=3.057
#   Mode 1: <hf|hf>_timemax=48.3, rho=6.95
#   Mode 2: <hf|hf>_timemax=126, rho=11.22
#   Mode 3: <hf|hf>_timemax=83.02, rho=9.112
#   Mode 4: <hf|hf>_timemax=32.08, rho=5.664
#   Mode 5: <hf|hf>_timemax=9.443, rho=3.073
#   Mode 6: <hf|hf>_timemax=2.379, rho=1.542
# rho_m: [ 3.05749996  6.94990468 11.22314952  9.11176203  5.66377984  3.07291007
#   1.5424536 ]
# Dominant mode index: 2, rho: 11.22
# beta=0.02157, rho_dom_M=11.22, rho_tot=18.71
# X_scalar (time-maximized): 5.012
# Time-maximized Log-likelihood: 0.973248
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.399, rho=3.066
#   Mode 1: <hf|hf>_timemax=48.58, rho=6.97
#   Mode 2: <hf|hf>_timemax=126.4, rho=11.24
#   Mode 3: <hf|hf>_timemax=83.22, rho=9.123
#   Mode 4: <hf|hf>_timemax=32.11, rho=5.667
#   Mode 5: <hf|hf>_timemax=9.466, rho=3.077
#   Mode 6: <hf|hf>_timemax=2.385, rho=1.544
# rho_m: [ 3.06585979  6.97025669 11.24402085  9.12264201  5.66670426  3.07669757
#   1.54436521]
# Dominant mode index: 2, rho: 11.24
# beta=0.02151, rho_dom_M=11.24, rho_tot=18.75
# X_scalar (time-maximized): 5.059
# Time-maximized Log-likelihood: 1.02055
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.448, rho=3.074
#   Mode 1: <hf|hf>_timemax=48.88, rho=6.991
#   Mode 2: <hf|hf>_timemax=126.9, rho=11.26
#   Mode 3: <hf|hf>_timemax=83.43, rho=9.134
#   Mode 4: <hf|hf>_timemax=32.18, rho=5.673
#   Mode 5: <hf|hf>_timemax=9.474, rho=3.078
#   Mode 6: <hf|hf>_timemax=2.387, rho=1.545
# rho_m: [ 3.07380366  6.99149179 11.26482544  9.13384068  5.67266914  3.07803952
#   1.54486568]
# Dominant mode index: 2, rho: 11.26
# beta=0.02142, rho_dom_M=11.26, rho_tot=18.79
# X_scalar (time-maximized): 5.15
# Time-maximized Log-likelihood: 1.02156
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.5, rho=3.082
#   Mode 1: <hf|hf>_timemax=49.17, rho=7.012
#   Mode 2: <hf|hf>_timemax=127.3, rho=11.28
#   Mode 3: <hf|hf>_timemax=83.63, rho=9.145
#   Mode 4: <hf|hf>_timemax=32.24, rho=5.678
#   Mode 5: <hf|hf>_timemax=9.482, rho=3.079
#   Mode 6: <hf|hf>_timemax=2.393, rho=1.547
# rho_m: [ 3.0822419   7.01222567 11.28437505  9.14518439  5.6783042   3.0793468
#   1.54688908]
# Dominant mode index: 2, rho: 11.28
# beta=0.02131, rho_dom_M=11.28, rho_tot=18.84
# X_scalar (time-maximized): 5.179
# Time-maximized Log-likelihood: 1.07248
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.551, rho=3.09
#   Mode 1: <hf|hf>_timemax=49.46, rho=7.033
#   Mode 2: <hf|hf>_timemax=127.9, rho=11.31
#   Mode 3: <hf|hf>_timemax=83.85, rho=9.157
#   Mode 4: <hf|hf>_timemax=32.29, rho=5.682
#   Mode 5: <hf|hf>_timemax=9.497, rho=3.082
#   Mode 6: <hf|hf>_timemax=2.396, rho=1.548
# rho_m: [ 3.09048194  7.0331211  11.30781028  9.1568383   5.68199397  3.0816538
#   1.54797237]
# Dominant mode index: 2, rho: 11.31
# beta=0.02127, rho_dom_M=11.31, rho_tot=18.86
# X_scalar (time-maximized): 5.389
# Time-maximized Log-likelihood: 1.18634
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.603, rho=3.099
#   Mode 1: <hf|hf>_timemax=49.76, rho=7.054
#   Mode 2: <hf|hf>_timemax=128.3, rho=11.33
#   Mode 3: <hf|hf>_timemax=84.01, rho=9.165
#   Mode 4: <hf|hf>_timemax=32.35, rho=5.688
#   Mode 5: <hf|hf>_timemax=9.521, rho=3.086
#   Mode 6: <hf|hf>_timemax=2.398, rho=1.549
# rho_m: [ 3.0989433   7.05436226 11.32760257  9.16546558  5.68802835  3.08559241
#   1.54857069]
# Dominant mode index: 2, rho: 11.33
# beta=0.02126, rho_dom_M=11.33, rho_tot=18.89
# X_scalar (time-maximized): 5.453
# Time-maximized Log-likelihood: 1.13332
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.656, rho=3.107
#   Mode 1: <hf|hf>_timemax=50.06, rho=7.075
#   Mode 2: <hf|hf>_timemax=128.8, rho=11.35
#   Mode 3: <hf|hf>_timemax=84.26, rho=9.179
#   Mode 4: <hf|hf>_timemax=32.43, rho=5.694
#   Mode 5: <hf|hf>_timemax=9.525, rho=3.086
#   Mode 6: <hf|hf>_timemax=2.398, rho=1.548
# rho_m: [ 3.10737785  7.07523765 11.3496394   9.17931492  5.69448516  3.08627987
#   1.54845158]
# Dominant mode index: 2, rho: 11.35
# beta=0.02122, rho_dom_M=11.35, rho_tot=18.91
# X_scalar (time-maximized): 5.173
# Time-maximized Log-likelihood: 1.07061
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.707, rho=3.116
#   Mode 1: <hf|hf>_timemax=50.36, rho=7.096
#   Mode 2: <hf|hf>_timemax=129.3, rho=11.37
#   Mode 3: <hf|hf>_timemax=84.46, rho=9.19
#   Mode 4: <hf|hf>_timemax=32.48, rho=5.699
#   Mode 5: <hf|hf>_timemax=9.55, rho=3.09
#   Mode 6: <hf|hf>_timemax=2.405, rho=1.551
# rho_m: [ 3.11563113  7.09646424 11.36903678  9.19012132  5.69889469  3.09033822
#   1.55082058]
# Dominant mode index: 2, rho: 11.37
# beta=0.02117, rho_dom_M=11.37, rho_tot=18.95
# X_scalar (time-maximized): 5.289
# Time-maximized Log-likelihood: 1.08807
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.76, rho=3.124
#   Mode 1: <hf|hf>_timemax=50.67, rho=7.118
#   Mode 2: <hf|hf>_timemax=129.7, rho=11.39
#   Mode 3: <hf|hf>_timemax=84.64, rho=9.2
#   Mode 4: <hf|hf>_timemax=32.53, rho=5.703
#   Mode 5: <hf|hf>_timemax=9.554, rho=3.091
#   Mode 6: <hf|hf>_timemax=2.407, rho=1.551
# rho_m: [ 3.1240276   7.11808993 11.38934024  9.20022707  5.70317097  3.09088287
#   1.55137558]
# Dominant mode index: 2, rho: 11.39
# beta=0.02111, rho_dom_M=11.39, rho_tot=18.98
# X_scalar (time-maximized): 5.198
# Time-maximized Log-likelihood: 0.858284
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.813, rho=3.133
#   Mode 1: <hf|hf>_timemax=50.97, rho=7.139
#   Mode 2: <hf|hf>_timemax=130.2, rho=11.41
#   Mode 3: <hf|hf>_timemax=84.86, rho=9.212
#   Mode 4: <hf|hf>_timemax=32.59, rho=5.708
#   Mode 5: <hf|hf>_timemax=9.568, rho=3.093
#   Mode 6: <hf|hf>_timemax=2.41, rho=1.552
# rho_m: [ 3.13259641  7.13940987 11.41058888  9.21181979  5.70834709  3.09317125
#   1.55238476]
# Dominant mode index: 2, rho: 11.41
# beta=0.02105, rho_dom_M=11.41, rho_tot=19.01
# X_scalar (time-maximized): 5.286
# Time-maximized Log-likelihood: 0.999356
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.868, rho=3.141
#   Mode 1: <hf|hf>_timemax=51.27, rho=7.16
#   Mode 2: <hf|hf>_timemax=130.7, rho=11.43
#   Mode 3: <hf|hf>_timemax=85.09, rho=9.224
#   Mode 4: <hf|hf>_timemax=32.65, rho=5.714
#   Mode 5: <hf|hf>_timemax=9.593, rho=3.097
#   Mode 6: <hf|hf>_timemax=2.414, rho=1.554
# rho_m: [ 3.14135118  7.16037296 11.43382266  9.22437283  5.71445423  3.09721557
#   1.5537341 ]
# Dominant mode index: 2, rho: 11.43
# beta=0.021, rho_dom_M=11.43, rho_tot=19.05
# X_scalar (time-maximized): 4.802
# Time-maximized Log-likelihood: 0.802677
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.922, rho=3.15
#   Mode 1: <hf|hf>_timemax=51.6, rho=7.183
#   Mode 2: <hf|hf>_timemax=131.2, rho=11.45
#   Mode 3: <hf|hf>_timemax=85.3, rho=9.236
#   Mode 4: <hf|hf>_timemax=32.7, rho=5.719
#   Mode 5: <hf|hf>_timemax=9.592, rho=3.097
#   Mode 6: <hf|hf>_timemax=2.413, rho=1.553
# rho_m: [ 3.14986601  7.18338945 11.45425844  9.23602702  5.71878362  3.09704772
#   1.55332076]
# Dominant mode index: 2, rho: 11.45
# beta=0.02094, rho_dom_M=11.45, rho_tot=19.08
# X_scalar (time-maximized): 5.066
# Time-maximized Log-likelihood: 0.961131
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=9.976, rho=3.159
#   Mode 1: <hf|hf>_timemax=51.9, rho=7.204
#   Mode 2: <hf|hf>_timemax=131.7, rho=11.47
#   Mode 3: <hf|hf>_timemax=85.49, rho=9.246
#   Mode 4: <hf|hf>_timemax=32.77, rho=5.724
#   Mode 5: <hf|hf>_timemax=9.621, rho=3.102
#   Mode 6: <hf|hf>_timemax=2.419, rho=1.555
# rho_m: [ 3.15853803  7.20418392 11.47431092  9.2463334   5.72425458  3.10174483
#   1.55527304]
# Dominant mode index: 2, rho: 11.47
# beta=0.02088, rho_dom_M=11.47, rho_tot=19.12
# X_scalar (time-maximized): 5.687
# Time-maximized Log-likelihood: 1.34526
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.03, rho=3.167
#   Mode 1: <hf|hf>_timemax=52.23, rho=7.227
#   Mode 2: <hf|hf>_timemax=132.2, rho=11.5
#   Mode 3: <hf|hf>_timemax=85.69, rho=9.257
#   Mode 4: <hf|hf>_timemax=32.81, rho=5.728
#   Mode 5: <hf|hf>_timemax=9.625, rho=3.102
#   Mode 6: <hf|hf>_timemax=2.423, rho=1.557
# rho_m: [ 3.16722826  7.22684451 11.49685761  9.25695079  5.72792518  3.10235705
#   1.55674621]
# Dominant mode index: 2, rho: 11.5
# beta=0.02081, rho_dom_M=11.5, rho_tot=19.16
# X_scalar (time-maximized): 4.972
# Time-maximized Log-likelihood: 0.853486
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.09, rho=3.176
#   Mode 1: <hf|hf>_timemax=52.53, rho=7.248
#   Mode 2: <hf|hf>_timemax=132.7, rho=11.52
#   Mode 3: <hf|hf>_timemax=85.93, rho=9.27
#   Mode 4: <hf|hf>_timemax=32.86, rho=5.733
#   Mode 5: <hf|hf>_timemax=9.639, rho=3.105
#   Mode 6: <hf|hf>_timemax=2.425, rho=1.557
# rho_m: [ 3.17581412  7.24767824 11.51976374  9.27003634  5.73261635  3.10470535
#   1.55731524]
# Dominant mode index: 2, rho: 11.52
# beta=0.02069, rho_dom_M=11.52, rho_tot=19.21
# X_scalar (time-maximized): 5.601
# Time-maximized Log-likelihood: 1.2785
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.14, rho=3.185
#   Mode 1: <hf|hf>_timemax=52.85, rho=7.27
#   Mode 2: <hf|hf>_timemax=133.2, rho=11.54
#   Mode 3: <hf|hf>_timemax=86.14, rho=9.281
#   Mode 4: <hf|hf>_timemax=32.93, rho=5.738
#   Mode 5: <hf|hf>_timemax=9.663, rho=3.108
#   Mode 6: <hf|hf>_timemax=2.425, rho=1.557
# rho_m: [ 3.1847684   7.26984756 11.54104147  9.28140271  5.73833595  3.1084821
#   1.55732531]
# Dominant mode index: 2, rho: 11.54
# beta=0.02063, rho_dom_M=11.54, rho_tot=19.24
# X_scalar (time-maximized): 5.206
# Time-maximized Log-likelihood: 0.9811
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.2, rho=3.193
#   Mode 1: <hf|hf>_timemax=53.17, rho=7.292
#   Mode 2: <hf|hf>_timemax=133.7, rho=11.56
#   Mode 3: <hf|hf>_timemax=86.32, rho=9.291
#   Mode 4: <hf|hf>_timemax=33.01, rho=5.745
#   Mode 5: <hf|hf>_timemax=9.659, rho=3.108
#   Mode 6: <hf|hf>_timemax=2.433, rho=1.56
# rho_m: [ 3.19344545  7.29155438 11.56283446  9.29095148  5.74504661  3.10796018
#   1.55974993]
# Dominant mode index: 2, rho: 11.56
# beta=0.02065, rho_dom_M=11.56, rho_tot=19.25
# X_scalar (time-maximized): 5.041
# Time-maximized Log-likelihood: 0.914875
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.26, rho=3.202
#   Mode 1: <hf|hf>_timemax=53.49, rho=7.314
#   Mode 2: <hf|hf>_timemax=134.2, rho=11.58
#   Mode 3: <hf|hf>_timemax=86.56, rho=9.304
#   Mode 4: <hf|hf>_timemax=33.04, rho=5.748
#   Mode 5: <hf|hf>_timemax=9.689, rho=3.113
#   Mode 6: <hf|hf>_timemax=2.433, rho=1.56
# rho_m: [ 3.20235452  7.31396854 11.58323526  9.30355186  5.74793843  3.11276328
#   1.55996365]
# Dominant mode index: 2, rho: 11.58
# beta=0.02061, rho_dom_M=11.58, rho_tot=19.28
# X_scalar (time-maximized): 5.135
# Time-maximized Log-likelihood: 0.881093
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.31, rho=3.211
#   Mode 1: <hf|hf>_timemax=53.83, rho=7.337
#   Mode 2: <hf|hf>_timemax=134.7, rho=11.6
#   Mode 3: <hf|hf>_timemax=86.78, rho=9.316
#   Mode 4: <hf|hf>_timemax=33.13, rho=5.756
#   Mode 5: <hf|hf>_timemax=9.701, rho=3.115
#   Mode 6: <hf|hf>_timemax=2.437, rho=1.561
# rho_m: [ 3.21122926  7.33657249 11.60451011  9.31553412  5.75598206  3.11460561
#   1.56095742]
# Dominant mode index: 2, rho: 11.6
# beta=0.02056, rho_dom_M=11.6, rho_tot=19.32
# X_scalar (time-maximized): 5.211
# Time-maximized Log-likelihood: 1.07571
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.37, rho=3.22
#   Mode 1: <hf|hf>_timemax=54.16, rho=7.359
#   Mode 2: <hf|hf>_timemax=135.2, rho=11.63
#   Mode 3: <hf|hf>_timemax=86.99, rho=9.327
#   Mode 4: <hf|hf>_timemax=33.18, rho=5.76
#   Mode 5: <hf|hf>_timemax=9.717, rho=3.117
#   Mode 6: <hf|hf>_timemax=2.442, rho=1.563
# rho_m: [ 3.2200531   7.35909129 11.62776786  9.32697027  5.76038314  3.11714519
#   1.56269142]
# Dominant mode index: 2, rho: 11.63
# beta=0.0205, rho_dom_M=11.63, rho_tot=19.35
# X_scalar (time-maximized): 5.375
# Time-maximized Log-likelihood: 1.05319
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.43, rho=3.229
#   Mode 1: <hf|hf>_timemax=54.48, rho=7.381
#   Mode 2: <hf|hf>_timemax=135.6, rho=11.65
#   Mode 3: <hf|hf>_timemax=87.2, rho=9.338
#   Mode 4: <hf|hf>_timemax=33.24, rho=5.766
#   Mode 5: <hf|hf>_timemax=9.723, rho=3.118
#   Mode 6: <hf|hf>_timemax=2.441, rho=1.562
# rho_m: [ 3.22927128  7.38083684 11.64681035  9.33806364  5.76578536  3.11816033
#   1.5622172 ]
# Dominant mode index: 2, rho: 11.65
# beta=0.0204, rho_dom_M=11.65, rho_tot=19.4
# X_scalar (time-maximized): 5.171
# Time-maximized Log-likelihood: 0.914845
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.48, rho=3.238
#   Mode 1: <hf|hf>_timemax=54.82, rho=7.404
#   Mode 2: <hf|hf>_timemax=136.2, rho=11.67
#   Mode 3: <hf|hf>_timemax=87.42, rho=9.35
#   Mode 4: <hf|hf>_timemax=33.3, rho=5.77
#   Mode 5: <hf|hf>_timemax=9.73, rho=3.119
#   Mode 6: <hf|hf>_timemax=2.446, rho=1.564
# rho_m: [ 3.23782669  7.40425498 11.67002322  9.34961889  5.77029947  3.11931101
#   1.56408553]
# Dominant mode index: 2, rho: 11.67
# beta=0.02033, rho_dom_M=11.67, rho_tot=19.44
# X_scalar (time-maximized): 5.541
# Time-maximized Log-likelihood: 1.04163
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.54, rho=3.247
#   Mode 1: <hf|hf>_timemax=55.16, rho=7.427
#   Mode 2: <hf|hf>_timemax=136.7, rho=11.69
#   Mode 3: <hf|hf>_timemax=87.63, rho=9.361
#   Mode 4: <hf|hf>_timemax=33.34, rho=5.774
#   Mode 5: <hf|hf>_timemax=9.743, rho=3.121
#   Mode 6: <hf|hf>_timemax=2.451, rho=1.565
# rho_m: [ 3.2470578   7.42670332 11.69180376  9.36134099  5.77410544  3.12142954
#   1.56543936]
# Dominant mode index: 2, rho: 11.69
# beta=0.02033, rho_dom_M=11.69, rho_tot=19.46
# X_scalar (time-maximized): 5.236
# Time-maximized Log-likelihood: 0.915007
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.6, rho=3.256
#   Mode 1: <hf|hf>_timemax=55.49, rho=7.449
#   Mode 2: <hf|hf>_timemax=137.2, rho=11.71
#   Mode 3: <hf|hf>_timemax=87.83, rho=9.372
#   Mode 4: <hf|hf>_timemax=33.41, rho=5.78
#   Mode 5: <hf|hf>_timemax=9.763, rho=3.125
#   Mode 6: <hf|hf>_timemax=2.452, rho=1.566
# rho_m: [ 3.25596792  7.44941564 11.71362271  9.37186562  5.77971807  3.12451643
#   1.56577937]
# Dominant mode index: 2, rho: 11.71
# beta=0.02028, rho_dom_M=11.71, rho_tot=19.49
# X_scalar (time-maximized): 5.848
# Time-maximized Log-likelihood: 1.2962
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.66, rho=3.266
#   Mode 1: <hf|hf>_timemax=55.83, rho=7.472
#   Mode 2: <hf|hf>_timemax=137.7, rho=11.73
#   Mode 3: <hf|hf>_timemax=88.06, rho=9.384
#   Mode 4: <hf|hf>_timemax=33.48, rho=5.786
#   Mode 5: <hf|hf>_timemax=9.771, rho=3.126
#   Mode 6: <hf|hf>_timemax=2.452, rho=1.566
# rho_m: [ 3.26560403  7.47216123 11.73424352  9.38428411  5.78645562  3.12590529
#   1.56602794]
# Dominant mode index: 2, rho: 11.73
# beta=0.02017, rho_dom_M=11.73, rho_tot=19.54
# X_scalar (time-maximized): 5.374
# Time-maximized Log-likelihood: 0.93648
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.72, rho=3.275
#   Mode 1: <hf|hf>_timemax=56.18, rho=7.496
#   Mode 2: <hf|hf>_timemax=138.3, rho=11.76
#   Mode 3: <hf|hf>_timemax=88.24, rho=9.394
#   Mode 4: <hf|hf>_timemax=33.54, rho=5.792
#   Mode 5: <hf|hf>_timemax=9.785, rho=3.128
#   Mode 6: <hf|hf>_timemax=2.458, rho=1.568
# rho_m: [ 3.27450573  7.49560004 11.75798363  9.39354063  5.79151232  3.12806388
#   1.5677454 ]
# Dominant mode index: 2, rho: 11.76
# beta=0.02016, rho_dom_M=11.76, rho_tot=19.56
# X_scalar (time-maximized): 5.777
# Time-maximized Log-likelihood: 1.09256
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.78, rho=3.284
#   Mode 1: <hf|hf>_timemax=56.52, rho=7.518
#   Mode 2: <hf|hf>_timemax=138.7, rho=11.78
#   Mode 3: <hf|hf>_timemax=88.45, rho=9.405
#   Mode 4: <hf|hf>_timemax=33.58, rho=5.794
#   Mode 5: <hf|hf>_timemax=9.808, rho=3.132
#   Mode 6: <hf|hf>_timemax=2.463, rho=1.569
# rho_m: [ 3.28368763  7.5179585  11.77815736  9.40491077  5.79443775  3.1317367
#   1.56936313]
# Dominant mode index: 2, rho: 11.78
# beta=0.02011, rho_dom_M=11.78, rho_tot=19.6
# X_scalar (time-maximized): 4.987
# Time-maximized Log-likelihood: 1.00176
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.84, rho=3.293
#   Mode 1: <hf|hf>_timemax=56.89, rho=7.542
#   Mode 2: <hf|hf>_timemax=139.3, rho=11.8
#   Mode 3: <hf|hf>_timemax=88.67, rho=9.416
#   Mode 4: <hf|hf>_timemax=33.64, rho=5.8
#   Mode 5: <hf|hf>_timemax=9.826, rho=3.135
#   Mode 6: <hf|hf>_timemax=2.465, rho=1.57
# rho_m: [ 3.29295727  7.54222616 11.80185051  9.41628147  5.79987337  3.13462022
#   1.56994249]
# Dominant mode index: 2, rho: 11.8
# beta=0.02002, rho_dom_M=11.8, rho_tot=19.64
# X_scalar (time-maximized): 5.117
# Time-maximized Log-likelihood: 0.889537
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.91, rho=3.303
#   Mode 1: <hf|hf>_timemax=57.23, rho=7.565
#   Mode 2: <hf|hf>_timemax=139.8, rho=11.82
#   Mode 3: <hf|hf>_timemax=88.92, rho=9.43
#   Mode 4: <hf|hf>_timemax=33.69, rho=5.804
#   Mode 5: <hf|hf>_timemax=9.838, rho=3.137
#   Mode 6: <hf|hf>_timemax=2.465, rho=1.57
# rho_m: [ 3.3025017   7.56487226 11.82366176  9.42995119  5.80449828  3.13651152
#   1.57003795]
# Dominant mode index: 2, rho: 11.82
# beta=0.01999, rho_dom_M=11.82, rho_tot=19.67
# X_scalar (time-maximized): 5.082
# Time-maximized Log-likelihood: 0.814238
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=10.97, rho=3.312
#   Mode 1: <hf|hf>_timemax=57.58, rho=7.588
#   Mode 2: <hf|hf>_timemax=140.3, rho=11.85
#   Mode 3: <hf|hf>_timemax=89.15, rho=9.442
#   Mode 4: <hf|hf>_timemax=33.78, rho=5.812
#   Mode 5: <hf|hf>_timemax=9.855, rho=3.139
#   Mode 6: <hf|hf>_timemax=2.472, rho=1.572
# rho_m: [ 3.31159853  7.58790234 11.84598474  9.44211046  5.81177507  3.13929209
#   1.57238314]
# Dominant mode index: 2, rho: 11.85
# beta=0.01994, rho_dom_M=11.85, rho_tot=19.7
# X_scalar (time-maximized): 4.922
# Time-maximized Log-likelihood: 0.966915
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=11.03, rho=3.321
#   Mode 1: <hf|hf>_timemax=57.96, rho=7.613
#   Mode 2: <hf|hf>_timemax=140.8, rho=11.87
#   Mode 3: <hf|hf>_timemax=89.36, rho=9.453
#   Mode 4: <hf|hf>_timemax=33.84, rho=5.817
#   Mode 5: <hf|hf>_timemax=9.852, rho=3.139
#   Mode 6: <hf|hf>_timemax=2.475, rho=1.573
# rho_m: [ 3.32115213  7.61283831 11.86798324  9.45312747  5.81684869  3.1388566
#   1.57328744]
# Dominant mode index: 2, rho: 11.87
# beta=0.01978, rho_dom_M=11.87, rho_tot=19.77
# X_scalar (time-maximized): 5.205
# Time-maximized Log-likelihood: 0.982181
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=11.09, rho=3.331
#   Mode 1: <hf|hf>_timemax=58.32, rho=7.637
#   Mode 2: <hf|hf>_timemax=141.4, rho=11.89
#   Mode 3: <hf|hf>_timemax=89.54, rho=9.463
#   Mode 4: <hf|hf>_timemax=33.87, rho=5.82
#   Mode 5: <hf|hf>_timemax=9.882, rho=3.144
#   Mode 6: <hf|hf>_timemax=2.479, rho=1.574
# rho_m: [ 3.3307213   7.6367074  11.89129788  9.46251662  5.81966807  3.14351657
#   1.57446817]
# Dominant mode index: 2, rho: 11.89
# beta=0.01983, rho_dom_M=11.89, rho_tot=19.78
# X_scalar (time-maximized): 5.54
# Time-maximized Log-likelihood: 1.02058
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=11.16, rho=3.34
#   Mode 1: <hf|hf>_timemax=58.68, rho=7.66
#   Mode 2: <hf|hf>_timemax=141.9, rho=11.91
#   Mode 3: <hf|hf>_timemax=89.76, rho=9.474
#   Mode 4: <hf|hf>_timemax=33.93, rho=5.825
#   Mode 5: <hf|hf>_timemax=9.896, rho=3.146
#   Mode 6: <hf|hf>_timemax=2.48, rho=1.575
# rho_m: [ 3.3399825   7.66021796 11.91314793  9.47392254  5.82529807  3.14582588
#   1.57469772]
# Dominant mode index: 2, rho: 11.91
# beta=0.01974, rho_dom_M=11.91, rho_tot=19.82
# X_scalar (time-maximized): 4.97
# Time-maximized Log-likelihood: 0.82316
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=11.22, rho=3.35
#   Mode 1: <hf|hf>_timemax=59.02, rho=7.683
#   Mode 2: <hf|hf>_timemax=142.5, rho=11.94
#   Mode 3: <hf|hf>_timemax=90, rho=9.487
#   Mode 4: <hf|hf>_timemax=33.99, rho=5.83
#   Mode 5: <hf|hf>_timemax=9.912, rho=3.148
#   Mode 6: <hf|hf>_timemax=2.482, rho=1.575
# rho_m: [ 3.34957109  7.68270939 11.93646562  9.48664884  5.82967652  3.14826644
#   1.57542053]
# Dominant mode index: 2, rho: 11.94
# beta=0.01972, rho_dom_M=11.94, rho_tot=19.85
# X_scalar (time-maximized): 5.089
# Time-maximized Log-likelihood: 0.770024
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=11.28, rho=3.359
#   Mode 1: <hf|hf>_timemax=59.4, rho=7.707
#   Mode 2: <hf|hf>_timemax=143, rho=11.96
#   Mode 3: <hf|hf>_timemax=90.24, rho=9.5
#   Mode 4: <hf|hf>_timemax=34.07, rho=5.837
#   Mode 5: <hf|hf>_timemax=9.91, rho=3.148
#   Mode 6: <hf|hf>_timemax=2.483, rho=1.576
# rho_m: [ 3.35893859  7.70696778 11.95905123  9.49963943  5.83702905  3.1480353
#   1.57589387]
# Dominant mode index: 2, rho: 11.96
# beta=0.01965, rho_dom_M=11.96, rho_tot=19.89
# X_scalar (time-maximized): 5.012
# Time-maximized Log-likelihood: 0.942554
# Waveform amplitudes (time-maximized):
#   Mode 0: <hf|hf>_timemax=11.35, rho=3.369
#   Mode 1: <hf|hf>_timemax=59.78, rho=7.732
#   Mode 2: <hf|hf>_timemax=143.6, rho=11.98
#   Mode 3: <hf|hf>_timemax=90.41, rho=9.509
#   Mode 4: <hf|hf>_timemax=34.13, rho=5.842
#   Mode 5: <hf|hf>_timemax=9.931, rho=3.151
#   Mode 6: <hf|hf>_timemax=2.486, rho=1.577
# rho_m: [ 3.36857249  7.73151398 11.98165404  9.50862517  5.84198423  3.15139771
#   1.5768447 ]
# Dominant mode index: 2, rho: 11.98
# beta=0.01961, rho_dom_M=11.98, rho_tot=19.92
# X_scalar (time-maximized): 5.047
# Time-maximized Log-likelihood: 0.889639

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(param_range, f_stats_tm,   label='fstat timemax only')
# plt.plot(param_range, f_stats_pm,   label='fstat phasemax only')
# plt.plot(param_range, f_stats_pure, label='fstat pure')
# plt.plot(param_range, f_stats_tmX, label='fstat timemax in X only')
# plt.plot(param_range, X_pure, label='X pure')
# plt.plot(param_range, X_tm, label='X timemax')
# plt.plot(param_range, X_tpm, label='X timemax +phasemax')
# plt.plot(param_range, Sfour, label='S4')
# plt.plot(param_range, Ssix, label='S6')
plt.plot(param_range, Stwelve, label='S12')
# plt.plot(param_range, Ssixteen, label='S16')
# plt.plot(param_range, Sp, label='S12 no timemax')

plt.xlim(0.975, 1.025)
plt.title('logm2 (TDI gen 1)')
plt.legend(loc='lower left')
plt.savefig('logden.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
fig_1d, axs_1d = plt.subplots(1, 5, figsize=(20, 4))
labels = [r'$\log_{10}(m_1)$', r'$\log_{10}(m_2)$', r'$a$', r'$p_0$', r'$e_0$', r'$T$']
plt.ylabel('logden', fontsize=12)
for dim in range(5):
    ax = axs_1d[dim]

    # Plot theoretical log-density
    ax.plot(line_points_proc1[dim], X_sc_line, '-', 
            color='blue', alpha=0.5, linewidth=2, label='semicoherent')


    # Mark the max likelihood points
    ax.axvline(proc1_maxld_pt_1d[dim], color='blue', linestyle='--', 
               alpha=0.5, label=f'Proc1 Max Logden Point')
    ax.axvline(param_true[dim], color='red', linestyle='--', 
               alpha=0.5, label='True Point')
    
    ax.set_xlabel(labels[dim], fontsize=12)
    # ax.set_ylabel('logden', fontsize=12)
    ax.grid(True, alpha=0.3)

plt.legend()
plt.tight_layout()

# %%
# Generate trajectory to get fundamental frequencies
print("Computing fundamental frequencies...")
from few.trajectory.inspiral import EMRIInspiral
from few.utils.constants import YRSID_SI

N_traj = 5000
delta_T = T*YRSID_SI/5000
traj_gen = EMRIInspiral(func='KerrEccEqFlux')
t_arr, p_arr, e_arr, x_arr, Phi_phi_arr, Phi_theta_arr, Phi_r_arr = traj_gen(
    m1, m2, a, p0, e0, xI0, T=T, dt=dt, upsample=True,
    Phi_phi0=Phi_phi0, Phi_theta0=Phi_theta0, Phi_r0=Phi_r0
)

# %%
from few.utils.utility import get_p_at_t

get_p_at_t(traj_module=traj_gen, t_out=1, traj_args=[m1, m2, a, e0, xI0])
